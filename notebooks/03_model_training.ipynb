# %% [markdown]
# # Base Model Training (Logistic Regression)

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
                            confusion_matrix, 
                            f1_score,
                            accuracy_score,
                            precision_score,
                            recall_score
                            )
warnings.filterwarnings('ignore')

# %%
seed = 42
np.random.seed(seed)

# %% [markdown]
# ### Load The Data

# %%
X_train = np.load('../artifacts/imbalance/X_train.npz')['arr_0']
Y_train = np.load('../artifacts/imbalance/Y_train.npz')['arr_0']
X_test = np.load('../artifacts/imbalance/X_test.npz')['arr_0']
Y_test = np.load('../artifacts/imbalance/Y_test.npz')['arr_0']


X_train_balance = np.load('../artifacts/balance/X_train.npz')['arr_0']
Y_train_balance = np.load('../artifacts/balance/Y_train.npz')['arr_0']
X_test_balance = np.load('../artifacts/balance/X_test.npz')['arr_0']
Y_test_balance = np.load('../artifacts/balance/Y_test.npz')['arr_0']

# %% [markdown]
# ### Model Training

# %%
model_lr_imbalanced = LogisticRegression(
                            random_state = 42,
                            max_iter = 1000      
                            )
model_lr_imbalanced.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
model_lr_balanced = LogisticRegression(
                            random_state = 42,
                            max_iter = 1000      
                            )
model_lr_balanced.fit(X_train_balance, Y_train_balance)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %% [markdown]
# ### Inference

# %%
Y_hat_train = model_lr_imbalanced.predict(X_train)
Y_hat_test = model_lr_imbalanced.predict(X_test)

Y_proba_train = model_lr_imbalanced.predict_proba(X_train)
Y_proba_test = model_lr_imbalanced.predict_proba(X_test)

# %%
Y_hat_train_balanced = model_lr_balanced.predict(X_train_balance)
Y_hat_test_balanced = model_lr_balanced.predict(X_test_balance)

Y_proba_train_balanced = model_lr_balanced.predict_proba(X_train_balance)
Y_proba_test_balanced = model_lr_balanced.predict_proba(X_test_balance)

# %% [markdown]
# ### Evaluation

# %%
accuracy_imbalanced = accuracy_score(Y_test, Y_hat_test)
precision_imbalanced = precision_score(Y_test, Y_hat_test)
recall_imbalanced = recall_score(Y_test, Y_hat_test)
f1_score_imbalanced = f1_score(Y_test, Y_hat_test)

# %%
accuracy_balanced = accuracy_score(Y_test_balance, Y_hat_test_balanced)
precision_balanced = precision_score(Y_test_balance, Y_hat_test_balanced)
recall_balanced = recall_score(Y_test_balance, Y_hat_test_balanced)
f1_score_balanced = f1_score(Y_test_balance, Y_hat_test_balanced)

# %%
print(f"accuracy imbalanced : {accuracy_imbalanced}")
print(f"precision imbalanced : {precision_imbalanced}")
print(f"recall imbalanced : {recall_imbalanced}")
print(f"f1_score imbalanced : {f1_score_imbalanced}")
# Out:
# accuracy imbalanced : 0.7796730632551528
# precision imbalanced : 0.6081081081081081
# recall imbalanced : 0.48128342245989303
# f1_score imbalanced : 0.5373134328358209

# %%
print(f"accuracy balanced : {accuracy_balanced}")
print(f"precision balanced : {precision_balanced}")
print(f"recall balanced : {recall_balanced}")
print(f"f1_score balanced : {f1_score_balanced}")
# Out:
# accuracy balanced : 0.7348969438521677
# precision balanced : 0.5008635578583766
# recall balanced : 0.7754010695187166
# f1_score balanced : 0.608604407135362

# %%
cm = confusion_matrix(Y_test, Y_hat_test)
sns.heatmap(cm, annot=True, fmt='d')
print("Confusion Matrix for Imbalanced Data")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

cm = confusion_matrix(Y_test_balance, Y_hat_test_balanced)
sns.heatmap(cm, annot=True, fmt='d')
print("Confusion Matrix for Balanced Data")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Confusion Matrix for Imbalanced Data
# Confusion Matrix for Balanced Data

# %% [markdown]
# ### Save Logistic Regression Model

# %%
import joblib

# Save the model to a file
joblib_file = "../models/logistic_regression_model_for_imbalanced.pkl"
joblib.dump(model_lr_imbalanced, joblib_file)

joblib_file = "../models/logistic_regression_model_for_balanced.pkl"
joblib.dump(model_lr_balanced, joblib_file)
# Out:
# ['../models/logistic_regression_model_for_balanced.pkl']

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

model_tree_imbalanced = DecisionTreeClassifier(random_state=42)
model_tree_imbalanced.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
model_tree_balanced = DecisionTreeClassifier(random_state=42)
model_tree_balanced.fit(X_train_balance, Y_train_balance)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ### Inference

# %%
Y_hat_train = model_tree_imbalanced.predict(X_train)
Y_hat_test = model_tree_imbalanced.predict(X_test)

Y_proba_train = model_tree_imbalanced.predict_proba(X_train)
Y_proba_test = model_tree_imbalanced.predict_proba(X_test)

# %%
Y_hat_train_balanced = model_tree_balanced.predict(X_train_balance)
Y_hat_test_balanced = model_tree_balanced.predict(X_test_balance)

Y_proba_train_balanced = model_tree_balanced.predict_proba(X_train_balance)
Y_proba_test_balanced = model_tree_balanced.predict_proba(X_test_balance)

# %% [markdown]
# ### Evaluation

# %%
accuracy_imbalanced = accuracy_score(Y_test, Y_hat_test)
precision_imbalanced = precision_score(Y_test, Y_hat_test)
recall_imbalanced = recall_score(Y_test, Y_hat_test)
f1_score_imbalanced = f1_score(Y_test, Y_hat_test)

# %%
accuracy_balanced = accuracy_score(Y_test_balance, Y_hat_test_balanced)
precision_balanced = precision_score(Y_test_balance, Y_hat_test_balanced)
recall_balanced = recall_score(Y_test_balance, Y_hat_test_balanced)
f1_score_balanced = f1_score(Y_test_balance, Y_hat_test_balanced)

# %%
print(f"accuracy imbalanced : {accuracy_imbalanced}")
print(f"precision imbalanced : {precision_imbalanced}")
print(f"recall imbalanced : {recall_imbalanced}")
print(f"f1_score imbalanced : {f1_score_imbalanced}")
# Out:
# accuracy imbalanced : 0.7043354655294953
# precision imbalanced : 0.4475
# recall imbalanced : 0.4786096256684492
# f1_score imbalanced : 0.4625322997416021

# %%
print(f"accuracy balanced : {accuracy_balanced}")
print(f"precision balanced : {precision_balanced}")
print(f"recall balanced : {recall_balanced}")
print(f"f1_score balanced : {f1_score_balanced}")
# Out:
# accuracy balanced : 0.7149964463397299
# precision balanced : 0.4679334916864608
# recall balanced : 0.5267379679144385
# f1_score balanced : 0.49559748427672956

# %%
cm = confusion_matrix(Y_test, Y_hat_test)
sns.heatmap(cm, annot=True, fmt='d')
print("Confusion Matrix for Imbalanced Data")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

cm = confusion_matrix(Y_test_balance, Y_hat_test_balanced)
sns.heatmap(cm, annot=True, fmt='d')
print("Confusion Matrix for Balanced Data")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Confusion Matrix for Imbalanced Data
# Confusion Matrix for Balanced Data

# %%
# Save the model to a file
joblib_file = "../models/decision_tree_model_for_imbalanced.pkl"
joblib.dump(model_tree_imbalanced, joblib_file)

joblib_file = "../models/decision_tree_model_for_balanced.pkl"
joblib.dump(model_tree_balanced, joblib_file)
# Out:
# ['../models/decision_tree_model_for_balanced.pkl']

# %% [markdown]
# # Bagging Method (Random Forest)

# %%
from sklearn.ensemble import RandomForestClassifier

model_forest_imbalanced = RandomForestClassifier(random_state=42, n_estimators=100)
model_forest_imbalanced.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
model_forest_balanced = RandomForestClassifier(random_state=42, n_estimators=100)
model_forest_balanced.fit(X_train_balance, Y_train_balance)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# ### Inference

# %%
Y_hat_train = model_forest_imbalanced.predict(X_train)
Y_hat_test = model_forest_imbalanced.predict(X_test)

Y_proba_train = model_forest_imbalanced.predict_proba(X_train)
Y_proba_test = model_forest_imbalanced.predict_proba(X_test)

# %%
Y_hat_train_balanced = model_forest_balanced.predict(X_train_balance)
Y_hat_test_balanced = model_forest_balanced.predict(X_test_balance)

Y_proba_train_balanced = model_forest_balanced.predict_proba(X_train_balance)
Y_proba_test_balanced = model_forest_balanced.predict_proba(X_test_balance)

# %% [markdown]
# ### Evaluation

# %%
accuracy_imbalanced = accuracy_score(Y_test, Y_hat_test)
precision_imbalanced = precision_score(Y_test, Y_hat_test)
recall_imbalanced = recall_score(Y_test, Y_hat_test)
f1_score_imbalanced = f1_score(Y_test, Y_hat_test)

# %%
accuracy_balanced = accuracy_score(Y_test_balance, Y_hat_test_balanced)
precision_balanced = precision_score(Y_test_balance, Y_hat_test_balanced)
recall_balanced = recall_score(Y_test_balance, Y_hat_test_balanced)
f1_score_balanced = f1_score(Y_test_balance, Y_hat_test_balanced)

# %%
print(f"accuracy imbalanced : {accuracy_imbalanced}")
print(f"precision imbalanced : {precision_imbalanced}")
print(f"recall imbalanced : {recall_imbalanced}")
print(f"f1_score imbalanced : {f1_score_imbalanced}")
# Out:
# accuracy imbalanced : 0.7803837953091685
# precision imbalanced : 0.6031746031746031
# recall imbalanced : 0.5080213903743316
# f1_score imbalanced : 0.5515239477503628

# %%
print(f"accuracy balanced : {accuracy_balanced}")
print(f"precision balanced : {precision_balanced}")
print(f"recall balanced : {recall_balanced}")
print(f"f1_score balanced : {f1_score_balanced}")
# Out:
# accuracy balanced : 0.7647476901208244
# precision balanced : 0.5570291777188329
# recall balanced : 0.5614973262032086
# f1_score balanced : 0.5592543275632489

# %%
cm = confusion_matrix(Y_test, Y_hat_test)
sns.heatmap(cm, annot=True, fmt='d')
print("Confusion Matrix for Imbalanced Data")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

cm = confusion_matrix(Y_test_balance, Y_hat_test_balanced)
sns.heatmap(cm, annot=True, fmt='d')
print("Confusion Matrix for Balanced Data")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Confusion Matrix for Imbalanced Data
# Confusion Matrix for Balanced Data

# %%
# Save the model to a file
joblib_file = "../models/random_forest_model_for_imbalanced.pkl"
joblib.dump(model_forest_imbalanced, joblib_file)

joblib_file = "../models/random_forest_model_for_balanced.pkl"
joblib.dump(model_forest_balanced, joblib_file)
# Out:
# ['../models/random_forest_model_for_balanced.pkl']

# %% [markdown]
# # Boosting Method (XGBoost)

# %%
from xgboost import XGBClassifier
model_xgb_imbalanced = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')
model_xgb_imbalanced.fit(X_train, Y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
model_xgb_balanced = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')
model_xgb_balanced.fit(X_train_balance, Y_train_balance)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %% [markdown]
# ### Inference

# %%
Y_hat_train = model_xgb_imbalanced.predict(X_train)
Y_hat_test = model_xgb_imbalanced.predict(X_test)

Y_proba_train = model_xgb_imbalanced.predict_proba(X_train)
Y_proba_test = model_xgb_imbalanced.predict_proba(X_test)

# %%
Y_hat_train_balanced = model_xgb_balanced.predict(X_train_balance)
Y_hat_test_balanced = model_xgb_balanced.predict(X_test_balance)

Y_proba_train_balanced = model_xgb_balanced.predict_proba(X_train_balance)
Y_proba_test_balanced = model_xgb_balanced.predict_proba(X_test_balance)

# %% [markdown]
# ### Evaluation

# %%
accuracy_imbalanced = accuracy_score(Y_test, Y_hat_test)
precision_imbalanced = precision_score(Y_test, Y_hat_test)
recall_imbalanced = recall_score(Y_test, Y_hat_test)
f1_score_imbalanced = f1_score(Y_test, Y_hat_test)

# %%
accuracy_balanced = accuracy_score(Y_test_balance, Y_hat_test_balanced)
precision_balanced = precision_score(Y_test_balance, Y_hat_test_balanced)
recall_balanced = recall_score(Y_test_balance, Y_hat_test_balanced)
f1_score_balanced = f1_score(Y_test_balance, Y_hat_test_balanced)

# %%
print(f"accuracy imbalanced : {accuracy_imbalanced}")
print(f"precision imbalanced : {precision_imbalanced}")
print(f"recall imbalanced : {recall_imbalanced}")
print(f"f1_score imbalanced : {f1_score_imbalanced}")
# Out:
# accuracy imbalanced : 0.7796730632551528
# precision imbalanced : 0.6019108280254777
# recall imbalanced : 0.5053475935828877
# f1_score imbalanced : 0.5494186046511628

# %%
print(f"accuracy balanced : {accuracy_balanced}")
print(f"precision balanced : {precision_balanced}")
print(f"recall balanced : {recall_balanced}")
print(f"f1_score balanced : {f1_score_balanced}")
# Out:
# accuracy balanced : 0.7619047619047619
# precision balanced : 0.5491183879093199
# recall balanced : 0.5828877005347594
# f1_score balanced : 0.5654993514915694

# %%
cm = confusion_matrix(Y_test, Y_hat_test)
sns.heatmap(cm, annot=True, fmt='d')
print("Confusion Matrix for Imbalanced Data")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

cm = confusion_matrix(Y_test_balance, Y_hat_test_balanced)
sns.heatmap(cm, annot=True, fmt='d')
print("Confusion Matrix for Balanced Data")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Confusion Matrix for Imbalanced Data
# Confusion Matrix for Balanced Data

# %%
# Save the model to a file
joblib_file = "../models/xgboost_model_for_imbalanced.pkl"
joblib.dump(model_xgb_imbalanced, joblib_file)

joblib_file = "../models/xgboost_model_for_balanced.pkl"
joblib.dump(model_xgb_balanced, joblib_file)
# Out:
# ['../models/xgboost_model_for_balanced.pkl']

# %% [markdown]
# # Advanced Boosting (CatBoost)

# %%
# !pip install catboost
# Out:
# ...
# WARNING: Ignoring invalid distribution ~nyio (C:\Users\DELL\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~nyio (C:\Users\DELL\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~nyio (C:\Users\DELL\anaconda3\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from catboost import CatBoostClassifier

model_cat_imbalanced = CatBoostClassifier(iterations=100, learning_rate=0.1, depth=6)
model_cat_imbalanced.fit(X_train, Y_train)
# Out:
# 0:	learn: 0.6282547	total: 166ms	remaining: 16.4s
# 1:	learn: 0.5791992	total: 177ms	remaining: 8.68s
# 2:	learn: 0.5421560	total: 184ms	remaining: 5.96s
# 3:	learn: 0.5138490	total: 190ms	remaining: 4.55s
# 4:	learn: 0.4915032	total: 194ms	remaining: 3.68s
# 5:	learn: 0.4756291	total: 198ms	remaining: 3.1s
# 6:	learn: 0.4645857	total: 202ms	remaining: 2.69s
# 7:	learn: 0.4548608	total: 207ms	remaining: 2.38s
# 8:	learn: 0.4459266	total: 211ms	remaining: 2.14s
# 9:	learn: 0.4383805	total: 216ms	remaining: 1.95s
# 10:	learn: 0.4326436	total: 221ms	remaining: 1.79s
# 11:	learn: 0.4276447	total: 225ms	remaining: 1.65s
# 12:	learn: 0.4238330	total: 229ms	remaining: 1.53s
# 13:	learn: 0.4201885	total: 234ms	remaining: 1.44s
# 14:	learn: 0.4168048	total: 238ms	remaining: 1.35s
# 15:	learn: 0.4141450	total: 242ms	remaining: 1.27s
# 16:	learn: 0.4116807	total: 247ms	remaining: 1.2s
# 17:	learn: 0.4094974	total: 251ms	remaining: 1.14s
# 18:	learn: 0.4073416	total: 255ms	remaining: 1.09s
# ...

# %%
model_cat_balanced = CatBoostClassifier(iterations=100, learning_rate=0.1, depth=6)
model_cat_balanced.fit(X_train_balance, Y_train_balance)
# Out:
# 0:	learn: 0.6401287	total: 7.12ms	remaining: 705ms
# 1:	learn: 0.6016803	total: 14.7ms	remaining: 719ms
# 2:	learn: 0.5733421	total: 21.2ms	remaining: 686ms
# 3:	learn: 0.5453123	total: 29.1ms	remaining: 698ms
# 4:	learn: 0.5215287	total: 35.3ms	remaining: 670ms
# 5:	learn: 0.5069863	total: 41.6ms	remaining: 651ms
# 6:	learn: 0.4947821	total: 48.3ms	remaining: 642ms
# 7:	learn: 0.4813689	total: 54.5ms	remaining: 626ms
# 8:	learn: 0.4723315	total: 62ms	remaining: 627ms
# 9:	learn: 0.4603623	total: 68.3ms	remaining: 614ms
# 10:	learn: 0.4496653	total: 75.2ms	remaining: 609ms
# 11:	learn: 0.4429882	total: 82.2ms	remaining: 602ms
# 12:	learn: 0.4345448	total: 88.4ms	remaining: 592ms
# 13:	learn: 0.4250935	total: 95.8ms	remaining: 588ms
# 14:	learn: 0.4194056	total: 102ms	remaining: 578ms
# 15:	learn: 0.4150159	total: 134ms	remaining: 704ms
# 16:	learn: 0.4110867	total: 140ms	remaining: 685ms
# 17:	learn: 0.4056422	total: 146ms	remaining: 664ms
# ...

# %% [markdown]
# ### Inference

# %%
Y_hat_train = model_xgb_imbalanced.predict(X_train)
Y_hat_test = model_xgb_imbalanced.predict(X_test)

Y_proba_train = model_xgb_imbalanced.predict_proba(X_train)
Y_proba_test = model_xgb_imbalanced.predict_proba(X_test)

# %%
Y_hat_train_balanced = model_xgb_balanced.predict(X_train_balance)
Y_hat_test_balanced = model_xgb_balanced.predict(X_test_balance)

Y_proba_train_balanced = model_xgb_balanced.predict_proba(X_train_balance)
Y_proba_test_balanced = model_xgb_balanced.predict_proba(X_test_balance)

# %% [markdown]
# ### Evaluation

# %%
accuracy_imbalanced = accuracy_score(Y_test, Y_hat_test)
precision_imbalanced = precision_score(Y_test, Y_hat_test)
recall_imbalanced = recall_score(Y_test, Y_hat_test)
f1_score_imbalanced = f1_score(Y_test, Y_hat_test)

# %%
accuracy_balanced = accuracy_score(Y_test_balance, Y_hat_test_balanced)
precision_balanced = precision_score(Y_test_balance, Y_hat_test_balanced)
recall_balanced = recall_score(Y_test_balance, Y_hat_test_balanced)
f1_score_balanced = f1_score(Y_test_balance, Y_hat_test_balanced)

# %%
print(f"accuracy imbalanced : {accuracy_imbalanced}")
print(f"precision imbalanced : {precision_imbalanced}")
print(f"recall imbalanced : {recall_imbalanced}")
print(f"f1_score imbalanced : {f1_score_imbalanced}")
# Out:
# accuracy imbalanced : 0.7796730632551528
# precision imbalanced : 0.6019108280254777
# recall imbalanced : 0.5053475935828877
# f1_score imbalanced : 0.5494186046511628

# %%
print(f"accuracy balanced : {accuracy_balanced}")
print(f"precision balanced : {precision_balanced}")
print(f"recall balanced : {recall_balanced}")
print(f"f1_score balanced : {f1_score_balanced}")
# Out:
# accuracy balanced : 0.7619047619047619
# precision balanced : 0.5491183879093199
# recall balanced : 0.5828877005347594
# f1_score balanced : 0.5654993514915694

# %%
cm = confusion_matrix(Y_test, Y_hat_test)
sns.heatmap(cm, annot=True, fmt='d')
print("Confusion Matrix for Imbalanced Data")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

cm = confusion_matrix(Y_test_balance, Y_hat_test_balanced)
sns.heatmap(cm, annot=True, fmt='d')
print("Confusion Matrix for Balanced Data")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Confusion Matrix for Imbalanced Data
# Confusion Matrix for Balanced Data

# %%
# Save the model to a file
joblib_file = "../models/catboost_model_for_imbalanced.pkl"
joblib.dump(model_cat_imbalanced, joblib_file)

joblib_file = "../models/catboost_model_for_balanced.pkl"
joblib.dump(model_cat_balanced, joblib_file)
# Out:
# ['../models/catboost_model_for_balanced.pkl']
